# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings("ignore")

from jupyterthemes import jtplot

jtplot.style(theme="monokai", context="notebook", ticks=True, grid=False)
df = pd.read_csv("cars.csv")
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945  $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820  $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990  $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195  $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755  $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    int64
#  10  MPG_City     428 non-null    int64
#  11  MPG_Highway  428 non-null    int64
#  12  Weight       428 non-null    int64
#  13  Wheelbase    428 non-null    int64
#  14  Length       428 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.3+ KB

# %%
df.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
df['MSRP'] = df['MSRP'].str.replace('$', '').replace(',', '', regex=True).astype(float)
df['Invoice'] = df['Invoice'].str.replace('$', '').replace(',', '', regex=True).astype(float)

df['MSRP'] = df['MSRP'].astype(int)
df['Invoice'] = df['Invoice'].astype(int)

df.head()
# Out:
#     Make           Model   Type Origin DriveTrain   MSRP  Invoice  EngineSize  \
# 0  Acura             MDX    SUV   Asia        All  36945    33337         3.5
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820    21761         2.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990    24647         2.4
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195    30299         3.2
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755    39014         3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0        6.0         265        17           23    4451        106     189
# 1        4.0         200        24           31    2778        101     172
# 2        4.0         200        22           29    3230        105     183
# 3        6.0         270        20           28    3575        108     186
# 4        6.0         225        18           24    3880        115     197

# %%
fig = px.scatter_matrix(df, dimensions=["MSRP", "Invoice", "EngineSize", "Cylinders", "Horsepower", "MPG_City", "MPG_Highway"], color="Origin")
fig.show()
# Out:
# <div>                            <div id="52e04756-9f7e-4be8-8ef4-851b0d17c0cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52e04756-9f7e-4be8-8ef4-851b0d17c0cf")) {                    Plotly.newPlot(                        "52e04756-9f7e-4be8-8ef4-851b0d17c0cf",                        [{"dimensions":[{"axis":{"matches":true},"label":"MSRP","values":[36945,23820,26990,33195,43755,46100,89765,20140,19110,27560,19860,18690,13270,14170,15850,19860,22260,17750,19490,23760,26960,24950,27450,33260,21589,10539,11839,11939,13839,15389,15389,19339,20339,24589,26189,18739,28495,29795,32445,31145,42845,52545,34895,36395,31849,20449,19635,16040,10280,11155,12360,13580,14630,18435,26000,20615,11905,45700,64800,39195,32350,31045,32415,41010,48450,55750,63200,
# ...

# %%
fig = plt.figure(figsize=(12, 6))
sns.pairplot(df[["MSRP", "Invoice", "EngineSize", "Cylinders", "Horsepower", "MPG_City", "MPG_Highway"]], diag_kind='kde')

# %%
columns = ["MSRP", "Invoice", "EngineSize", "Cylinders", "Horsepower", "MPG_City", "MPG_Highway"]
plt.figure(figsize=(12, 6))
for i in range(len(columns)):
    plt.subplot(2, 4, i + 1)
    sns.displot(df[columns[i]], color='g')
    plt.title(columns[i])

# %%
fig = plt.figure(figsize=(12, 6))
sns.pairplot(df)
